# %%
import pandas as pd

# %%
car_sales = pd.read_csv('7.1 car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.loc[4]#refers to index
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
car_sales.iloc[4]#refers to position
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Make'] == 'Nissan']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 4  Nissan  White         213095      4  $3,500.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales[car_sales['Make'] == 'Toyota'].count()
# Out:
# Make             4
# Colour           4
# Odometer (KM)    4
# Doors            4
# Price            4
# dtype: int64

# %%
car_sales[car_sales['Odometer (KM)'] > 85000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors']) #this function crosses over the two columns together
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(['Make']).sum()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW             11179      5
# Honda          188335     12
# Nissan         244695      8
# Toyota         341805     15

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
#converting the price column to an integer
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales['Price']
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
seats_column = pd.Series([5,5,5,5,5,5])

car_sales['Seats'] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    5.0
# 6   Honda   Blue          45698      4   750000    NaN
# 7   Honda   Blue          54738      4   700000    NaN
# 8  Toyota  White          60000      4   625000    NaN
# 9  Nissan  White          31600      4   970000    NaN

# %%
car_sales['Seats'].fillna(5, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    5.0
# 6   Honda   Blue          45698      4   750000    5.0
# 7   Honda   Blue          54738      4   700000    5.0
# 8  Toyota  White          60000      4   625000    5.0
# 9  Nissan  White          31600      4   970000    5.0

# %%
car_sales['Fuel per 100KM'] = [12.3,14.5,12,11.3,5,3,5.6,3.4,9.4,7.4]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   400000    5.0            12.3
# 1   Honda    Red          87899      4   500000    5.0            14.5
# 2  Toyota   Blue          32549      3   700000    5.0            12.0
# 3     BMW  Black          11179      5  2200000    5.0            11.3
# 4  Nissan  White         213095      4   350000    5.0             5.0
# 5  Toyota  Green          99213      4   450000    5.0             3.0
# 6   Honda   Blue          45698      4   750000    5.0             5.6
# 7   Honda   Blue          54738      4   700000    5.0             3.4
# 8  Toyota  White          60000      4   625000    5.0             9.4
# 9  Nissan  White          31600      4   970000    5.0             7.4

# %%
car_sales['Total fuel used(L)'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0            12.3
# 1   Honda    Red          87899      4   500000    5.0            14.5
# 2  Toyota   Blue          32549      3   700000    5.0            12.0
# 3     BMW  Black          11179      5  2200000    5.0            11.3
# 4  Nissan  White         213095      4   350000    5.0             5.0
# 5  Toyota  Green          99213      4   450000    5.0             3.0
# 6   Honda   Blue          45698      4   750000    5.0             5.6
# 7   Honda   Blue          54738      4   700000    5.0             3.4
# 8  Toyota  White          60000      4   625000    5.0             9.4
# 9  Nissan  White          31600      4   970000    5.0             7.4
#
#    Total fuel used(L)
# 0           18455.289
# 1           12745.355
# 2            3905.880
# 3            1263.227
# 4           10654.750
# 5            2976.390
# 6            2559.088
# ...

# %%
car_sales['Total fuel used'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0            12.3
# 1   Honda    Red          87899      4   500000    5.0            14.5
# 2  Toyota   Blue          32549      3   700000    5.0            12.0
# 3     BMW  Black          11179      5  2200000    5.0            11.3
# 4  Nissan  White         213095      4   350000    5.0             5.0
# 5  Toyota  Green          99213      4   450000    5.0             3.0
# 6   Honda   Blue          45698      4   750000    5.0             5.6
# 7   Honda   Blue          54738      4   700000    5.0             3.4
# 8  Toyota  White          60000      4   625000    5.0             9.4
# 9  Nissan  White          31600      4   970000    5.0             7.4
#
#    Total fuel used(L)  Total fuel used
# 0           18455.289        18455.289
# 1           12745.355        12745.355
# 2            3905.880         3905.880
# ...

# %%
car_sales['Number of wheels'] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0            12.3
# 1   Honda    Red          87899      4   500000    5.0            14.5
# 2  Toyota   Blue          32549      3   700000    5.0            12.0
# 3     BMW  Black          11179      5  2200000    5.0            11.3
# 4  Nissan  White         213095      4   350000    5.0             5.0
# 5  Toyota  Green          99213      4   450000    5.0             3.0
# 6   Honda   Blue          45698      4   750000    5.0             5.6
# 7   Honda   Blue          54738      4   700000    5.0             3.4
# 8  Toyota  White          60000      4   625000    5.0             9.4
# 9  Nissan  White          31600      4   970000    5.0             7.4
#
#    Total fuel used(L)  Total fuel used  Number of wheels
# 0           18455.289        18455.289                 4
# 1           12745.355        12745.355                 4
# ...

# %%
car_sales['passed road safety'] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0            12.3
# 1   Honda    Red          87899      4   500000    5.0            14.5
# 2  Toyota   Blue          32549      3   700000    5.0            12.0
# 3     BMW  Black          11179      5  2200000    5.0            11.3
# 4  Nissan  White         213095      4   350000    5.0             5.0
# 5  Toyota  Green          99213      4   450000    5.0             3.0
# 6   Honda   Blue          45698      4   750000    5.0             5.6
# 7   Honda   Blue          54738      4   700000    5.0             3.4
# 8  Toyota  White          60000      4   625000    5.0             9.4
# 9  Nissan  White          31600      4   970000    5.0             7.4
#
#    Total fuel used(L)  Total fuel used  Number of wheels  passed road safety
# 0           18455.289        18455.289                 4                True
# ...

# %%
car_sales.drop('Total fuel used', axis=1, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0            12.3
# 1   Honda    Red          87899      4   500000    5.0            14.5
# 2  Toyota   Blue          32549      3   700000    5.0            12.0
# 3     BMW  Black          11179      5  2200000    5.0            11.3
# 4  Nissan  White         213095      4   350000    5.0             5.0
# 5  Toyota  Green          99213      4   450000    5.0             3.0
# 6   Honda   Blue          45698      4   750000    5.0             5.6
# 7   Honda   Blue          54738      4   700000    5.0             3.4
# 8  Toyota  White          60000      4   625000    5.0             9.4
# 9  Nissan  White          31600      4   970000    5.0             7.4
#
#    Total fuel used(L)  Number of wheels  passed road safety
# 0           18455.289                 4                True
# 1           12745.355                 4                True
# ...

# %%
# convereting the odometer from KM to MILES (KM TO MILES IS BY DIVIDING BY 1.6)
#this lambda function allows for calculation, whereby x represents the value to b calculated on.
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White      93776.875      4   400000    5.0            12.3
# 1   Honda    Red      54936.875      4   500000    5.0            14.5
# 2  Toyota   Blue      20343.125      3   700000    5.0            12.0
# 3     BMW  Black       6986.875      5  2200000    5.0            11.3
# 4  Nissan  White     133184.375      4   350000    5.0             5.0
# 5  Toyota  Green      62008.125      4   450000    5.0             3.0
# 6   Honda   Blue      28561.250      4   750000    5.0             5.6
# 7   Honda   Blue      34211.250      4   700000    5.0             3.4
# 8  Toyota  White      37500.000      4   625000    5.0             9.4
# 9  Nissan  White      19750.000      4   970000    5.0             7.4
#
#    Total fuel used(L)  Number of wheels  passed road safety
# 0           18455.289                 4                True
# 1           12745.355                 4                True
# ...

# %%
car_sales.to_csv('improved_car_sales')
